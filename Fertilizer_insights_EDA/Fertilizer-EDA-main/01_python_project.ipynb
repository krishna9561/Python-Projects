# %%
import numpy as np
import pandas as pd
import matplotlib
import sys
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\KRISHNA\Desktop\Fertilizer.csv")
df
# Out:
#      District_Name Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  \
# 0         Kolhapur      Black        75          50        100  6.5      1000
# 1         Kolhapur      Black        80          50        100  6.5      1000
# 2         Kolhapur      Black        85          50        100  6.5      1000
# 3         Kolhapur      Black        90          50        100  6.5      1000
# 4         Kolhapur      Black        95          50        100  6.5      1000
# ...            ...        ...       ...         ...        ...  ...       ...
# 4508          Pune      Black       130          80        150  7.0      1400
# 4509          Pune      Black       135          80        150  7.0      1400
# 4510          Pune      Black       140          80        150  7.0      1400
# 4511          Pune      Black       145          80        150  7.0      1400
# 4512          Pune      Black       150          80        150  7.0      1400
#
# ...

# %%
# 1.What are the data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4513 entries, 0 to 4512
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   District_Name  4513 non-null   object
#  1   Soil_color     4513 non-null   object
#  2   Nitrogen       4513 non-null   int64
#  3   Phosphorus     4513 non-null   int64
#  4   Potassium      4513 non-null   int64
#  5   pH             4513 non-null   float64
#  6   Rainfall       4513 non-null   int64
#  7   Temperature    4513 non-null   int64
#  8   Crop           4513 non-null   object
#  9   Fertilizer     4513 non-null   object
#  10  Link           4513 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 388.0+ KB

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium           pH     Rainfall  \
# count  4513.000000  4513.000000  4513.000000  4513.000000  4513.000000
# mean     95.409927    54.341901    63.595170     6.715267   819.189010
# std      38.060648    16.551991    35.691911     0.625198   251.730813
# min      20.000000    10.000000     5.000000     5.500000   300.000000
# 25%      60.000000    40.000000    40.000000     6.000000   600.000000
# 50%     105.000000    55.000000    55.000000     6.500000   800.000000
# 75%     125.000000    65.000000    75.000000     7.000000  1000.000000
# max     150.000000    90.000000   150.000000     8.500000  1700.000000
#
#        Temperature
# count  4513.000000
# mean     25.915134
# std       5.897328
# min      10.000000
# 25%      20.000000
# 50%      25.000000
# 75%      30.000000
# max      40.000000

# %%
df.columns
# Out:
# Index(['District_Name', 'Soil_color', 'Nitrogen', 'Phosphorus', 'Potassium',
#        'pH', 'Rainfall', 'Temperature', 'Crop', 'Fertilizer', 'Link'],
#       dtype='object')

# %%
# 2.How many rows and columns are present in the dataset
df.shape
# Out:
# (4513, 11)

# %%
# 3.Are there any missing values? If yes, in which columns and how many?
df.isna().sum()
# Out:
# District_Name    0
# Soil_color       0
# Nitrogen         0
# Phosphorus       0
# Potassium        0
# pH               0
# Rainfall         0
# Temperature      0
# Crop             0
# Fertilizer       0
# Link             0
# dtype: int64

# %%
# 4.Are there any duplicate rows in the dataset?
a=df[df.duplicated()]
b=df.duplicated()
print(a)
print(b)
# Out:
# Empty DataFrame
# Columns: [District_Name, Soil_color, Nitrogen, Phosphorus, Potassium, pH, Rainfall, Temperature, Crop, Fertilizer, Link]
# Index: []
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4508    False
# 4509    False
# 4510    False
# 4511    False
# 4512    False
# Length: 4513, dtype: bool

# %%
# 5 What is the mean, median, min, and max of Nitrogen, Phosphorus, and Potassium?

df[['Nitrogen','Phosphorus','Potassium']].agg(['min','max','mean','sum','median'])
# Out:
#              Nitrogen     Phosphorus     Potassium
# min         20.000000      10.000000       5.00000
# max        150.000000      90.000000     150.00000
# mean        95.409927      54.341901      63.59517
# sum     430585.000000  245245.000000  287005.00000
# median     105.000000      55.000000      55.00000

# %%
# 6 Are there any outliers in Nitrogen, Phosphorus, or Potassium? (Use boxplots)
df.boxplot(column=['Nitrogen', 'Phosphorus','Potassium'])
plt.show()

# %%
sns.boxplot(data=df[['Nitrogen', 'Phosphorus','Potassium']])
plt.show()

# %%
# 5 What is the distribution of Nitrogen? (Histogram + KDE)
sns.histplot(df['Nitrogen'], kde=True)   # kde=True adds the smooth curve
plt.show()

# %%
# 6 What is the distribution of Phosphorus and Potassium ?
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
sns.histplot(df['Phosphorus'], kde=True, bins=30)   # kde=True adds the smooth curve


plt.subplot(1,2,2)
sns.histplot(df['Potassium'], kde=True,bins=30)   # kde=True adds the smooth curve
plt.show()

# %%
#  7. Which nutrient shows the highest variation
df[['Potassium','Phosphorus','Nitrogen']].std()
# Out:
# Potassium     35.691911
# Phosphorus    16.551991
# Nitrogen      38.060648
# dtype: float64

# %%
# 8 What percentage of samples have Nitrogen < 80?
percentage = (df['Nitrogen'].lt(80).mean()) * 100
print(f"Percentage: {percentage:.2f}%")
# Out:
# Percentage: 33.28%

# %%
p=(df['Nitrogen']<80).mean()*100
print(p)
# Out:
# 33.28163084422779

# %%
# 9. What percentage of samples have Potassium < 120?
per=(df['Potassium']<120).mean()*100
print(per)
# Out:
# 84.2011965433193

# %%
# 10 .What soil colors are present in the dataset?
df['Soil_color'].unique()
# Out:
# array(['Black', 'Red ', 'Medium Brown', 'Dark Brown', 'Red',
#        'Light Brown', 'Reddish Brown'], dtype=object)

# %%
# 11 .Which crop is most commonly grown?
df['Crop'].value_counts().head(1)
# Out:
# Crop
# Sugarcane    1010
# Name: count, dtype: int64

# %%
# 12 .How many unique fertilizers are used in the dataset?
a=df['Fertilizer'].unique()
b=df['Fertilizer'].value_counts().head(1)
print(a)
print("<------------------------->")
print(b)
# Out:
# ['Urea' 'DAP' 'MOP' '10:26:26 NPK' 'SSP' 'Magnesium Sulphate'
#  '13:32:26 NPK' '12:32:16 NPK' '50:26:26 NPK' '19:19:19 NPK'
#  'Chilated Micronutrient' '18:46:00 NPK' 'Sulphur' '20:20:20 NPK'
#  'Ammonium Sulphate' 'Ferrous Sulphate' 'White Potash' '10:10:10 NPK'
#  'Hydrated Lime']
# <------------------------->
# Fertilizer
# Urea    1364
# Name: count, dtype: int64

# %%
# 13 For each crop, what is the average NPK value?
df.groupby('Crop')[['Potassium','Phosphorus','Nitrogen']].mean()
# Out:
#             Potassium  Phosphorus    Nitrogen
# Crop
# Cotton      60.769231   56.730769  117.615385
# Ginger      70.000000   50.000000   50.000000
# Gram        21.153846   39.615385   34.615385
# Grapes     130.000000   50.000000   90.000000
# Groundnut   27.881356   41.440678   29.406780
# Jowar       36.598985   37.030457   54.631980
# Maize       49.657143   70.000000  135.000000
# Masoor      22.500000   22.500000   45.000000
# Moong       20.909091   26.818182   50.909091
# Rice        48.349515   47.281553   92.427184
# Soybean     25.000000   35.000000   50.000000
# Sugarcane  113.980198   70.628713  131.613861
# Tur         23.214286   36.785714   38.571429
# Turmeric    44.909091   39.636364   39.727273
# Urad        25.000000   35.000000   48.181818
# Wheat       49.738068   53.119907   91.757858

# %%
# 14.Which fertilizer is used most frequently per crop?
df.groupby('Crop')['Fertilizer'].agg(lambda x:x.value_counts().idxmax())
# Out:
# Crop
# Cotton                          DAP
# Ginger                         Urea
# Gram                            DAP
# Grapes             Ferrous Sulphate
# Groundnut    Chilated Micronutrient
# Jowar                  10:26:26 NPK
# Maize                           SSP
# Masoor                         Urea
# Moong                           MOP
# Rice                           Urea
# Soybean                        Urea
# Sugarcane                       MOP
# Tur                            Urea
# Turmeric               White Potash
# Urad                           Urea
# Wheat                  19:19:19 NPK
# Name: Fertilizer, dtype: object

# %%
# 15 .What is the distribution of soil pH?
df['pH'].describe()
# Out:
# count    4513.000000
# mean        6.715267
# std         0.625198
# min         5.500000
# 25%         6.000000
# 50%         6.500000
# 75%         7.000000
# max         8.500000
# Name: pH, dtype: float64

# %%
# 16 How many soils are acidic, neutral, or alkaline?
df['pH_type'] = df['pH'].apply(
    lambda x: 'acidic' if x < 7 else ('neutral' if x == 7 else 'alkaline')
)

df['pH_type'].value_counts()
# Out:
# pH_type
# acidic      2439
# neutral     1101
# alkaline     973
# Name: count, dtype: int64

# %%
# 17 What is the average rainfall and temperature in the dataset?
df[["Temperature" ,"Rainfall"]].mean()
# Out:
# Temperature     25.915134
# Rainfall       819.189010
# dtype: float64

# %%
#  18 .Is rainfall correlated with temperature? (Scatter + correlation)
plt.scatter(df['Temperature'],df['Rainfall'])
plt.xlabel('Rainfall')
plt.ylabel('Temprature')
plt.title("Scatter Plot: Rainfall vs Temperature")
plt.show()
correlation = df['Rainfall'].corr(df['Temperature'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.3150453125614614

# %%
# 19 .What is the correlation between Nitrogen, Phosphorus, Potassium, pH, Rainfall, and Temperature? 
# (Correlation heatmap)
plt.figure(figsize=(13,5))
col=['Nitrogen', 'Phosphorus', 'Potassium', 'pH', 'Rainfall','Temperature']
sns.heatmap(df[col].corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
col=df[['Nitrogen', 'Phosphorus', 'Potassium', 'pH', 'Rainfall','Temperature']].corr()
col
# Out:
#              Nitrogen  Phosphorus  Potassium        pH  Rainfall  Temperature
# Nitrogen     1.000000    0.709539   0.584315  0.182850  0.269364    -0.010213
# Phosphorus   0.709539    1.000000   0.573970  0.244945  0.225453    -0.055303
# Potassium    0.584315    0.573970   1.000000  0.075110  0.445671     0.053413
# pH           0.182850    0.244945   0.075110  1.000000  0.097884    -0.002949
# Rainfall     0.269364    0.225453   0.445671  0.097884  1.000000     0.315045
# Temperature -0.010213   -0.055303   0.053413 -0.002949  0.315045     1.000000

# %%
# 20 Does higher rainfall relate to higher Nitrogen levels?
df['Rainfall'].corr(df['Nitrogen'])
# Out:
# np.float64(0.2693637848046554)

# %%
plt.scatter(df['Rainfall'],df['Nitrogen'])
plt.xlabel('Rainfall')
plt.ylabel('Nitrogen')
plt.title('Rainfall vs Nitrogen')
plt.show()

# %%
# 21. Does pH affect any nutrient values
df[['pH','Nitrogen','Phosphorus','Potassium']].corr()['pH']
# Out:
# pH            1.000000
# Nitrogen      0.182850
# Phosphorus    0.244945
# Potassium     0.075110
# Name: pH, dtype: float64

# %%
sns.heatmap(df[['pH', 'Nitrogen', 'Phosphorus', 'Potassium']].corr(),
            annot=True, cmap='coolwarm')
plt.show()

# %%
# 22. Use a pairplot: Do nutrients show any visible relationship?
cols=['Nitrogen','Phosphorus','Potassium']
sns.pairplot(df[cols])
plt.show()

# %%
# 23. Which crop requires the highest Nitrogen?
df.groupby('Crop')['Nitrogen'].mean().head(1)
# Out:
# Crop
# Cotton    117.615385
# Name: Nitrogen, dtype: float64

# %%
# 24.Which crop has the highest average NPK total?
df.groupby('Crop')[['Nitrogen','Phosphorus','Potassium']].mean().sum(axis=1).idxmax()
# Out:
# 'Sugarcane'

# %%
# 25.Do different crops show different pH preferences?
df.groupby('Crop')['pH'].mean()
# Out:
# Crop
# Cotton       6.956154
# Ginger       5.980000
# Gram         6.480769
# Grapes       6.720000
# Groundnut    6.508475
# Jowar        6.757614
# Maize        6.610000
# Masoor       6.250000
# Moong        6.636364
# Rice         6.519417
# Soybean      6.500000
# Sugarcane    6.864851
# Tur          6.357143
# Turmeric     6.181818
# Urad         6.727273
# Wheat        6.733411
# Name: pH, dtype: float64

# %%
# 26.What is the distribution of fertilizer usage?
plt.figure(figsize=(13,6))
df['Fertilizer'].value_counts().plot(kind='bar')
plt.title('distribution of fertilizer')
plt.xlabel('Ferilizer')
plt.ylabel('# COUNT')
plt.show()

# %%
# 27.For each fertilizer, what is the average NPK applied?
df.groupby('Fertilizer')[['Nitrogen', 'Phosphorus', 'Potassium']].mean()
# Out:
#                           Nitrogen  Phosphorus   Potassium
# Fertilizer
# 10:10:10 NPK             90.000000   50.000000  130.000000
# 10:26:26 NPK             54.711538   36.442308   36.346154
# 12:32:16 NPK            109.905660   62.971698   55.613208
# 13:32:26 NPK            125.000000   50.000000   62.500000
# 18:46:00 NPK             45.000000   27.500000   12.500000
# 19:19:19 NPK             91.177083   52.718750   49.614583
# 20:20:20 NPK             50.000000   35.000000   25.000000
# 50:26:26 NPK             90.524194   46.814516   48.346774
# Ammonium Sulphate        50.000000   50.000000   70.000000
# Chilated Micronutrient   29.166667   41.250000   27.777778
# DAP                     111.649175   60.532234   80.727136
# Ferrous Sulphate         76.764706   47.352941  107.500000
# Hydrated Lime            90.000000   50.000000  130.000000
# MOP                     116.532399   64.054291   83.931699
# Magnesium Sulphate      119.279070   55.116279   63.023256
# ...

# %%
#  27 .Which fertilizer is used when Nitrogen is lowest?

df[df['Nitrogen'] == df['Nitrogen'].min()]['Fertilizer'].value_counts().head(1)
# Out:
# Fertilizer
# Chilated Micronutrient    30
# Name: count, dtype: int64

# %%
# 28 .Is there any pattern in NPK values across rainfall levels?
avg_npk = df.groupby('Rainfall')[['Nitrogen','Phosphorus','Potassium']].mean()

avg_npk.plot(marker='o')
plt.xlabel("Rainfall Range")
plt.ylabel("Average NPK")
plt.title("NPK Patterns Across Rainfall Levels")
plt.show()

# %%
# 29.Does temperature influence the recommended fertilizer?
plt.figure(figsize=(13,6))
df.groupby('Fertilizer')['Temperature'].mean()
sns.boxplot(data=df, x='Fertilizer', y='Temperature')
plt.title("Temperature vs Fertilizer")
plt.show()

# %%
# 30 Create a nutrient score (NPK_total): which crop has the highest?
df['NPK_total'] = df['Nitrogen'] + df['Phosphorus'] + df['Potassium']
df.groupby('Crop')['NPK_total'].mean().head(1)
# Out:
# Crop
# Cotton    235.115385
# Name: NPK_total, dtype: float64
